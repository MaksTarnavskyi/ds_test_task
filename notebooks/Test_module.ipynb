# %%
#autoreload modules after changes
# %load_ext autoreload
# %autoreload 2

# %%
from module.Preprocessor import Preprocessor

preprocessor = Preprocessor()

preprocessor.fit_train(train_filename="data/train.tsv")

# %%
preprocessor.process_test(test_filename="data/test.tsv", output_folder="result",
                          output_filename="test_proc.tsv",process_method="standardization")

# %%
import pandas as pd

proc_test = pd.read_csv("result/test_proc.tsv", sep="\t")
proc_test.head(4)
# Out:
#                 id_job  feature_2_stand_0  feature_2_stand_1  \
# 0 -9168029089769934848           0.769135           0.234307
# 1 -9167993139315005440          -0.496788           0.234307
# 2 -9167993136660569088          -0.502214           0.234307
# 3 -9167993126042826752          -0.688485           0.232522
#
#    feature_2_stand_2  feature_2_stand_3  feature_2_stand_4  feature_2_stand_5  \
# 0           0.720399           0.696881          -0.576915           0.803130
# 1          -0.162567           0.092944           0.584295          -0.398820
# 2          -0.447395          -0.091390           0.419332          -0.131720
# 3          -0.874636          -0.564352           0.545480          -0.622516
#
#    feature_2_stand_6  feature_2_stand_7  feature_2_stand_8  ...  \
# 0           0.258285           0.706847           0.808236  ...
# 1           0.294103           0.030519          -0.419534  ...
# 2           0.272612          -0.225390          -0.333323  ...
# 3           0.458866          -0.758096          -0.814918  ...
#
#    feature_2_stand_248  feature_2_stand_249  feature_2_stand_250  \
# 0             0.829606             0.772527             0.120503
# 1            -0.189921             0.021303             0.438698
# 2            -0.358414            -0.323721             0.379037
# 3            -0.895308            -0.703004             0.546657
#
#    feature_2_stand_251  feature_2_stand_252  feature_2_stand_253  \
# 0             0.802841            -0.502010             0.184573
# 1             0.201120             0.419363             0.468833
# 2            -0.028107             0.436516             0.305383
# 3            -1.034160             0.480624             0.497259
#
#    feature_2_stand_254  feature_2_stand_255  max_feature_2_index  \
# 0             0.798240             0.731307                  161
# 1            -0.005895            -0.275757                  161
# 2            -0.277769            -0.890851                  161
# 3            -0.890443            -1.017487                  161
#
#    max_feature_2_abs_mean_diff
# 0                    116.24781
# 1                    116.24781
# 2                    116.24781
# 3                    116.24781
#
# [4 rows x 259 columns]
